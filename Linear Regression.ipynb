# %% [markdown]
# # Boston Housing DataSet Machine Learning Exercise

# %%
#importing various tools/modules for machine learning
import numpy as np

import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

from matplotlib.animation import FuncAnimation

# %%
#sklearn imprts to import data sets
from sklearn.datasets import load_boston
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from IPython.display import HTML

# %% [markdown]
# # Data processing

# %% [markdown]
# This includes loading the dataset from sklearn adn then storing its 2 parts into two different dataframes and then concat the two dataframes using pandas

# %%
#load DataSet
boston=load_boston()
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
#data is transferred to pandas dataframe

features=pd.DataFrame(boston.data,columns=boston.feature_names )
target=pd.DataFrame(boston.target,columns=['Target'])

# %%
#basically boston has 2 part one(each being an array conmtianing different informations) is dataty and other being target, here we are storing each part in a different data set named features:data  and target:target
print(boston)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
print(features)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
print(target)
# Out:
#      Target
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
# ..      ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
#
# [506 rows x 1 columns]

# %%
#Accessing features

print(features['AGE'])
# Out:
# 0      65.2
# 1      78.9
# 2      61.1
# 3      45.8
# 4      54.2
#        ...
# 501    69.1
# 502    76.7
# 503    91.0
# 504    89.3
# 505    80.8
# Name: AGE, Length: 506, dtype: float64

# %%
print(features)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
print(max(target['Target']))
# Out:
# 50.0

# %%
print(min(target['Target']))
# Out:
# 5.0

# %%
#concatenate features and target
#axis=1 means concat side by side as default concat is up and down 

df=pd.concat([features,target],axis=1)

# %% [markdown]
# # VisualiVisualisation of DataSet

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
#description of df dataframe 
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# # Correlation between target and Attribute

# %% [markdown]
# Correlation states that 2 variable are dependent/ interrelated to each other with a positive or a negative correlation.
#
# ---> if positve correlation then x increase with y increase and vice versa
# ---> if negative correlation then x decrease with y increase and vice versa
#
#                              this is one of the way to perform linear regression

# %%
#calculate correlation between every column on the data 
#pandas provide a function named corr, here pearson is the method of correlation that gives standard correlation
corr=df.corr('pearson')

#take absolute value of correlation and find the attribute with highest correlation with target
corrs=[abs(corr[attr]['Target']) for attr in list(features)]

#make a list of pairs [(corr,feature)]
l=list(zip(corrs,list(features)))

#sort the list of pair in reverse/descending order
l.sort(key=lambda x:x[0],reverse=True)

#unzip pairs to two list
corrs,labels=list(zip((*l)))

#plot correlation with respect to the target variable as a bar graph
index=np.arange(len(labels))
plt.figure(figsize=(15,5))
plt.bar(index,corrs,width=0.5)
plt.xlabel('Atrributes')
plt.ylabel('correlation with the target variable')
plt.xticks(index,labels)
plt.show()

# %% [markdown]
# # Normalization of Data

# %% [markdown]
# Normalization means rescaling the data according to our own scale.here LSTAT and target are of different scaale and cannot be compared and plotted properly, to solve the problem we normalize the data (eg scale from 0 to 1)

# %%
#Assigning values

x=df['LSTAT'].values
y=df['Target'].values

# %%
print(x[:5])
print(y[:5])
# Out:
# [4.98 9.14 4.03 2.94 5.33]
# [24.  21.6 34.7 33.4 36.2]

# %%
x_scaler=MinMaxScaler()
x=x_scaler.fit_transform(x.reshape(-1,1))
x=x[:,-1]

# %%
y_scaler=MinMaxScaler()
y=y_scaler.fit_transform(y.reshape(-1,1))
y=y[:,-1]

# %%
print(len(x))
print(len(y))
#values are ranged from 0 to 5
# Out:
# 506
# 506

# %% [markdown]
# # Splitting the dataset

# %% [markdown]
# Splitting the datasset into two dataset named training dataset and testing dataset
# we were having two columns mainly.. that is x:features and y:targets... thus we will get 4 collection of data

# %%
xtrain,ytest,ytrain,xtest=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# # Mean Squared Error

# %%
#Error Function
def error(m,x,c,t):
    N=x.size
    e=sum(((m*x+c)-t)**2)
    return e*1/(2*N)

# %%
#Update function 
def update(m,x,c,t,learning_rate):
    grad_m=sum(2*((m*x+c)-t)*x)
    grad_c=sum(2*((m*x+c)-t))
    m=m-grad_m*learning_rate
    c=c-grad_c*learning_rate
    return m,c

# %% [raw]
# # The parameter may be changed to varied to observe the computation vs accuracy tradeoffs

# %% [markdown]
# <b>Learning rate</b> : Increasing the learning rate reduces the convergence time,but if the learning rate is too high the model will overshoot the minima.

# %% [markdown]
# <b>Iterations</b>: Number of iteration must be large enough to allow the model to converge to a minima,but if it is too large, then the model becomes too specific to the training data thus causing overfitting i.e., the model "memorizes" the data instead of learning the data.

# %% [markdown]
# <b>Error threshold</b>: This value can be set to a maximum value of error that is acceptable. When the error value goes below the treshold, the gradient descent is stopped

# %% [markdown]
# <b>Initial values</b> : for this problem where our objective is to determine the line which gives the least error, it does not matter what initial values you provide. but for non-convex optimization problems, initial values affect the learning process.

# %%
def gradient_descent(init_m,init_c,x,t,learning_rate,iterations,error_threshold):
    m=init_m
    c=init_c
    error_values=list()
    mc_values=list()
    for i in range(iterations):
        e=error(m,x,c,t)
        if e<error_threshold:
            print("Error is less than threshold, stopping gradient descent")
            break
        error_values.append(e)
        m,c=update(m,x,c,t,learning_rate)
        mc_values.append((m,c))
    return m,c,error_values,mc_values

# %%
# %%time
init_m=0.9
init_c=0
learning_rate=0.001
iterations=250
error_threshold=0.001
m,c,error_values,mc_values=gradient_descent(init_m,init_c,xtrain,ytrain,learning_rate,iterations,error_threshold)
# Out:
# Wall time: 167 ms

# %%
#plotting the regression curve
plt.scatter(xtrain,ytrain,color='b')
plt.plot(xtrain,(m*xtrain+c),color='r')

# %%
#plotting the error
plt.plot(np.arange(len(mc_values)),error_values)
plt.ylabel("Error")
plt.xlabel("Iteration")
# Out:
# Text(0.5, 0, 'Iteration')

# %% [markdown]
# # Visulization of Model

# %%
#split the data to lessen the load
mc_values_anim=mc_values[0:250:5]

# %%
fig,ax=plt.subplots()

ln, =plt.plot([],[],'ro-',animated=True)

def init():
    plt.scatter(xtrain,ytrain,color='b')
    ax.set_xlim(0,1.0)
    ax.set_ylim(0,1.0)
    return ln,

def update_frame(frame):
    m,c=mc_values_anim[frame]
    x1,y1=-0.5,m*-.5+c
    x2,y2=1.5,m*1.5+c
    ln.set_data([x1,x2],[y1,y2])
    return ln,

anim= FuncAnimation(fig,update_frame,frames=range(len(mc_values_anim)),init_func=init,blit=False)
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
predicted=m*(xtest)+c

# %%
mean_squared_error(ytest,predicted)
# Out:
# 0.014937343057265174

# %%
p=pd.DataFrame(list(zip(xtest,ytest,predicted)),columns=["x","target_y","predicted_y"])
p.head()
# Out:
#           x  target_y  predicted_y
# 0  0.028889  0.779249     0.593560
# 1  0.100000  0.616722     0.540809
# 2  0.395556  0.077539     0.321562
# 3  0.513333  0.211093     0.234193
# 4  0.600000  0.034492     0.169903

# %%
plt.scatter(xtest,ytest,color="b")
plt.plot(xtest,predicted,color='r')

# %%
predicted=predicted.reshape(-1,1)
xtest=xtest.reshape(-1,1)
ytest=ytest.reshape(-1,1)

xtest_scaled=x_scaler.inverse_transform(xtest)
ytest_scaled=y_scaler.inverse_transform(ytest)
predicted_scaled=y_scaler.inverse_transform(predicted)

xtest_scaled=xtest_scaled[:,-1]
ytest_scaled=ytest_scaled[:,-1]
predicted_scaled=predicted_scaled[:,-1]

p=pd.DataFrame(list(zip(xtest_scaled,ytest_scaled,predicted_scaled)),columns=["x_test","y_test","predicted"])
p.round(decimals=2)
p.head()
# Out:
#       x_test     y_test  predicted
# 0   2.776933  40.066225  31.710207
# 1   5.354000  32.752483  29.336407
# 2  16.064933   8.489238  19.470302
# 3  20.333200  14.499172  15.538696
# 4  23.474000   6.552152  12.645628
